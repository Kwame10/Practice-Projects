# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ds=pd.read_csv('census_income_project.csv')
ds
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
df=pd.DataFrame(data=ds)
df.shape
# Out:
# (32560, 15)

# %%
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.isnull())
plt.show()

# %% [markdown]
# The data has no null values

# %%
df.dtypes.sort_values(ascending=False)
# Out:
# Workclass         object
# Education         object
# Marital_status    object
# Occupation        object
# Relationship      object
# Race              object
# Sex               object
# Native_country    object
# Income            object
# Age                int64
# Fnlwgt             int64
# Education_num      int64
# Capital_gain       int64
# Capital_loss       int64
# Hours_per_week     int64
# dtype: object

# %%
#converting string data into integer

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
list1=['Workclass','Education','Marital_status','Occupation','Relationship','Race','Sex',
       'Native_country','Income']
for val in list1:
    df[val]=le.fit_transform(df[val].astype(str))
    
    
df
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0       50          6   83311          9             13               2
# 1       38          4  215646         11              9               0
# 2       53          4  234721          1              7               2
# 3       28          4  338409          9             13               2
# 4       37          4  284582         12             14               2
# ...    ...        ...     ...        ...            ...             ...
# 32555   27          4  257302          7             12               2
# 32556   40          4  154374         11              9               2
# 32557   58          4  151910         11              9               6
# 32558   22          4  201490         11              9               4
# 32559   52          5  287927         11              9               2
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# ...

# %%
df.dtypes
# Out:
# Age               int64
# Workclass         int64
# Fnlwgt            int64
# Education         int64
# Education_num     int64
# Marital_status    int64
# Occupation        int64
# Relationship      int64
# Race              int64
# Sex               int64
# Capital_gain      int64
# Capital_loss      int64
# Hours_per_week    int64
# Native_country    int64
# Income            int64
# dtype: object

# %%
df.corr()
# Out:
#                      Age  Workclass    Fnlwgt  Education  Education_num  \
# Age             1.000000   0.003786 -0.076646  -0.010508       0.036527
# Workclass       0.003786   1.000000 -0.016587   0.023537       0.052015
# Fnlwgt         -0.076646  -0.016587  1.000000  -0.028156      -0.043159
# Education      -0.010508   0.023537 -0.028156   1.000000       0.359172
# Education_num   0.036527   0.052015 -0.043159   0.359172       1.000000
# Marital_status -0.266292  -0.064798  0.028184  -0.038398      -0.069338
# Occupation     -0.020946   0.255004  0.001554  -0.021274       0.109748
# Relationship   -0.263698  -0.090449  0.008922  -0.010879      -0.094145
# Race            0.028718   0.049720 -0.021278   0.014135       0.031825
# Sex             0.088832   0.095942  0.026882  -0.027349       0.012256
# Capital_gain    0.077674   0.033828  0.000437   0.030047       0.122627
# Capital_loss    0.057775   0.012231 -0.010259   0.016744       0.079932
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# Key Observations:
# 1. The data shows predominant lower positive correlation values across all the columns.
# 2. The highest positive correlation identified is between Education and Education_num, followed by Education_num and Income.
# 3. The is a high negative correlation between sex and relationship per the data.
# 4. The highest positive correlation with income is Education_num, but income is highly negatively co

# %%
df.corr()['Income'].sort_values(ascending=False)
# Out:
# Income            1.000000
# Education_num     0.335182
# Age               0.234039
# Hours_per_week    0.229690
# Capital_gain      0.223333
# Sex               0.215995
# Capital_loss      0.150523
# Education         0.079311
# Occupation        0.075448
# Race              0.071853
# Workclass         0.051645
# Native_country    0.015845
# Fnlwgt           -0.009481
# Marital_status   -0.199295
# Relationship     -0.250924
# Name: Income, dtype: float64

# %% [markdown]
# key observations:

# %%
df.describe().T
# Out:
#                   count           mean            std      min       25%  \
# Age             32560.0      38.581634      13.640642     17.0      28.0
# Workclass       32560.0       3.868796       1.455879      0.0       4.0
# Fnlwgt          32560.0  189781.814373  105549.764924  12285.0  117831.5
# Education       32560.0      10.298249       3.870317      0.0       9.0
# Education_num   32560.0      10.080590       2.572709      1.0       9.0
# Marital_status  32560.0       2.611794       1.506225      0.0       2.0
# Occupation      32560.0       6.572912       4.228809      0.0       3.0
# Relationship    32560.0       1.446376       1.606794      0.0       0.0
# Race            32560.0       3.665848       0.848817      0.0       4.0
# Sex             32560.0       0.669195       0.470510      0.0       0.0
# Capital_gain    32560.0    1077.615172    7385.402999      0.0       0.0
# Capital_loss    32560.0      87.306511     402.966116      0.0       0.0
# ...

# %% [markdown]
# Key Observation:
# 1. It could be seen that the data has has high maximum values than the 75th percentile in some columns indicating the presence of outliers
# 2. Some of the columns have lower mean values than the midian(50th percentile) indicating skewness in the data
# 3. Some of the columns have zero 25th, 50th, and 75th percentiles but have only maximum values

# %%
df.skew()
# Out:
# Age                0.558738
# Workclass         -0.752280
# Fnlwgt             1.446972
# Education         -0.934063
# Education_num     -0.311630
# Marital_status    -0.013448
# Occupation         0.114540
# Relationship       0.786784
# Race              -2.435332
# Sex               -0.719244
# Capital_gain      11.953690
# Capital_loss       4.594549
# Hours_per_week     0.227636
# Native_country    -3.658235
# Income             1.212383
# dtype: float64

# %%
df.plot(kind='density',subplots=True,sharex=False,fontsize=1,figsize=(10,8),layout=(3,5))
plt.show()

# %%
x=df.drop(['Income'],axis=1)
y=df['Income']

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 32555    0
# 32556    1
# 32557    0
# 32558    0
# 32559    1
# Name: Income, Length: 32560, dtype: int64

# %%
x
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0       50          6   83311          9             13               2
# 1       38          4  215646         11              9               0
# 2       53          4  234721          1              7               2
# 3       28          4  338409          9             13               2
# 4       37          4  284582         12             14               2
# ...    ...        ...     ...        ...            ...             ...
# 32555   27          4  257302          7             12               2
# 32556   40          4  154374         11              9               2
# 32557   58          4  151910         11              9               6
# 32558   22          4  201490         11              9               4
# 32559   52          5  287927         11              9               2
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# ...

# %%
x.shape
# Out:
# (32560, 14)

# %%
x.skew().sort_values(ascending=True)
# Out:
# Native_country    -3.658235
# Race              -2.435332
# Education         -0.934063
# Workclass         -0.752280
# Sex               -0.719244
# Education_num     -0.311630
# Marital_status    -0.013448
# Occupation         0.114540
# Hours_per_week     0.227636
# Age                0.558738
# Relationship       0.786784
# Fnlwgt             1.446972
# Capital_loss       4.594549
# Capital_gain      11.953690
# dtype: float64

# %%
#correcting the skewness

# %%
from sklearn.preprocessing import power_transform

# %%
x_new=power_transform(x)
x_new
# Out:
# array([[ 0.89194657,  1.64422286, -1.08988899, ..., -0.2212132 ,
#         -2.22151541,  0.32907402],
#        [ 0.10271742,  0.01186427,  0.39874263, ..., -0.2212132 ,
#         -0.03557001,  0.32907402],
#        [ 1.06438077,  0.01186427,  0.56254016, ..., -0.2212132 ,
#         -0.03557001,  0.32907402],
#        ...,
#        [ 1.33455598,  0.01186427, -0.2197547 , ..., -0.2212132 ,
#         -0.03557001,  0.32907402],
#        [-1.35834148,  0.01186427,  0.27166793, ..., -0.2212132 ,
#         -1.65499204,  0.32907402],
#        [ 1.00782289,  0.79430139,  0.98216482, ..., -0.2212132 ,
#         -0.03557001,  0.32907402]])

# %%
pd.DataFrame(x_new,columns=x.columns).skew().sort_values(ascending=False)
# Out:
# Capital_loss      4.299511
# Capital_gain      3.016951
# Hours_per_week    0.229556
# Relationship      0.122917
# Workclass         0.061629
# Education_num     0.023885
# Fnlwgt            0.016914
# Age              -0.013897
# Marital_status   -0.114201
# Occupation       -0.187152
# Education        -0.309431
# Sex              -0.719244
# Race             -2.010817
# Native_country   -2.725467
# dtype: float64

# %%
x=pd.DataFrame(x_new,columns=x.columns)
x
# Out:
#             Age  Workclass    Fnlwgt  Education  Education_num  \
# 0      0.891947   1.644223 -1.089889  -0.477012       1.164793
# 1      0.102717   0.011864  0.398743   0.090482      -0.464330
# 2      1.064381   0.011864  0.562540  -2.067600      -1.200274
# 3     -0.731663   0.011864  1.340398  -0.477012       1.164793
# 4      0.028023   0.011864  0.957182   0.395133       1.600809
# ...         ...        ...       ...        ...            ...
# 32555 -0.827983   0.011864  0.746749  -0.984718       0.739697
# 32556  0.247374   0.011864 -0.193298   0.090482      -0.464330
# 32557  1.334556   0.011864 -0.219755   0.090482      -0.464330
# 32558 -1.358341   0.011864  0.271668   0.090482      -0.464330
# 32559  1.007823   0.794301  0.982165   0.090482      -0.464330
#
#        Marital_status  Occupation  Relationship      Race       Sex  \
# 0           -0.383427   -0.502825     -1.094635  0.412893  0.703087
# 1           -1.782434   -0.013085      0.134511  0.412893  0.703087
# ...

# %%
x.skew()
# Out:
# Age              -0.013897
# Workclass         0.061629
# Fnlwgt            0.016914
# Education        -0.309431
# Education_num     0.023885
# Marital_status   -0.114201
# Occupation       -0.187152
# Relationship      0.122917
# Race             -2.010817
# Sex              -0.719244
# Capital_gain      3.016951
# Capital_loss      4.299511
# Hours_per_week    0.229556
# Native_country   -2.725467
# dtype: float64

# %% [markdown]
# The skewness has been reduced

# %%
df['Income'].hist()
plt.title('Measure of Income')
plt.show()

df['Income'].value_counts()
# Out:
# 0    24719
# 1     7841
# Name: Income, dtype: int64

# %%
le.inverse_transform([0,1])
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %% [markdown]
# This indicate labels for the income levels: <=50K is 0, and >50K is 1

# %%
#Correcting inbalance in data

# %%
import sklearn
from imblearn.over_sampling import SMOTE

import warnings
warnings.filterwarnings('ignore')

# %%
smt=SMOTE()
trainx,trainy=smt.fit_resample(x,y)

# %%
trainx.value_counts()
# Out:
# Age        Workclass  Fnlwgt     Education  Education_num  Marital_status  Occupation  Relationship  Race      Sex        Capital_gain  Capital_loss  Hours_per_week  Native_country
# -1.029685  0.011864    0.220938  -1.792489  -2.733071       0.919719        0.631713    0.134511     0.412893  -1.422298  -0.30137      -0.221213     -0.035570       -3.221223         3
#  0.386185  0.011864    0.296705   1.387031  -0.075517      -0.383427        0.829763   -1.094635     0.412893   0.703087  -0.30137      -0.221213     -0.035570        0.329074         3
# -1.725471  0.011864   -0.886168   0.090482  -0.464330       0.919719       -0.250258    0.134511     0.412893   0.703087  -0.30137      -0.221213     -0.035570        0.329074         2
# -0.126492  0.011864    1.612567   0.090482  -0.464330      -1.782434        0.426075    0.134511     0.412893  -1.422298  -0.30137      -0.221213     -0.035570        0.329074         2
# ...

# %%
trainy.value_counts()
# Out:
# 0    24719
# 1    24719
# Name: Income, dtype: int64

# %%
sns.countplot(trainy)

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# The data is balanced now

# %%
#Checking outliers

# %%
x.boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
#Confirming the Outliers

# %%
from scipy.stats import zscore
(np.abs(zscore(x))<3).all().all()
# Out:
# False

# %%
z=np.abs(zscore(df))
z
# Out:
#             Age  Workclass    Fnlwgt  Education  Education_num  \
# 0      0.837097   1.463883  1.008742   0.335443       1.134779
# 1      0.042640   0.090121  0.245046   0.181319       0.420027
# 2      1.057031   0.090121  0.425770   2.402489       1.197429
# 3      0.775755   0.090121  1.408146   0.335443       1.134779
# 4      0.115952   0.090121  0.898170   0.439700       1.523480
# ...         ...        ...       ...        ...            ...
# 32555  0.849066   0.090121  0.639710   0.852204       0.746077
# 32556  0.103982   0.090121  0.335466   0.181319       0.420027
# 32557  1.423589   0.090121  0.358811   0.181319       0.420027
# 32558  1.215624   0.090121  0.110927   0.181319       0.420027
# 32559  0.983720   0.777002  0.929862   0.181319       0.420027
#
#        Marital_status  Occupation  Relationship      Race       Sex  \
# 0            0.406183    0.608434      0.900177  0.393675  0.703087
# 1            1.734026    0.135480      0.277810  0.393675  0.703087
# ...

# %%
#Removing Outliers

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0       50          6   83311          9             13               2
# 1       38          4  215646         11              9               0
# 2       53          4  234721          1              7               2
# 4       37          4  284582         12             14               2
# 5       49          4  160187          6              5               3
# ...    ...        ...     ...        ...            ...             ...
# 32555   27          4  257302          7             12               2
# 32556   40          4  154374         11              9               2
# 32557   58          4  151910         11              9               6
# 32558   22          4  201490         11              9               4
# 32559   52          5  287927         11              9               2
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# ...

# %%
print('Old df: ',df.shape)
print('New df: ',df_new.shape)
print('Total dropped: ',df.shape[0]-df_new.shape[0])
# Out:
# Old df:  (32560, 15)
# New df:  (27417, 15)
# Total dropped:  5143

# %%
#Splitting the data

# %%
x=df_new.drop(['Income'],axis=1)
y=df_new['Income']

# %%
x.shape
# Out:
# (27417, 14)

# %%
y.shape
# Out:
# (27417,)

# %%
#Training the data

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

import warnings
warnings.filterwarnings('ignore')

# %%
knn=KNeighborsClassifier()
dtc=DecisionTreeClassifier()
svc=SVC()

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)

Model=[knn,dtc,svc]

for m in Model:
    m.fit(x_train,y_train)
    m.score(x_train,y_train)
    predm=m.predict(x_test)
    print('Accuracy score of',m, 'is:')
    print(accuracy_score(y_test,predm))
    print(confusion_matrix(y_test,predm))
    print(classification_report(y_test,predm))
    print('\n')
# Out:
# Accuracy score of KNeighborsClassifier() is:
# 0.7822757111597374
# [[5946  443]
#  [1348  489]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.93      0.87      6389
#            1       0.52      0.27      0.35      1837
#
#     accuracy                           0.78      8226
#    macro avg       0.67      0.60      0.61      8226
# weighted avg       0.75      0.78      0.75      8226
#
#
#
# Accuracy score of DecisionTreeClassifier() is:
# 0.8090201799173353
# [[5571  818]
#  [ 753 1084]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.88      6389
#            1       0.57      0.59      0.58      1837
#
#     accuracy                           0.81      8226
#    macro avg       0.73      0.73      0.73      8226
# weighted avg       0.81      0.81      0.81      8226
#
#
#
# Accuracy score of SVC() is:
# 0.8070751276440554
# [[6384    5]
#  [1582  255]]
# ...

# %% [markdown]
# The above indicates that SVC model has the highest accuracy

# %%
#Prediction

# %%
def testpredict(s):
    s=s.reshape(1,-1)
    print('s shape is', s.shape)
    predincome=svc.predict(s)
    print(predincome)

# %%
s=np.array([50,6,83311,9,13,2,4,0,4,1,0,0,13,39])
testpredict(s)
# Out:
# s shape is (1, 14)
# [0]

# %% [markdown]
# With the above data as supplied by the S list, the outcome indicates that the individual's income is less or equal to 50k
